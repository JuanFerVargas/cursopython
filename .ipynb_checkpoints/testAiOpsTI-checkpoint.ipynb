# %%
#utiliza esta celda si haras el ejecicio en google colab

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ####Estas son las librerías que utilizaras para esta prueba técnica, NO las elimines, pues todas son requeridas para esta prueba

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
from math import ceil
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score

# %% [markdown]
# La finalidad de este proyecto es analizar los datos proporcionados en dataset AbandonoEmpleados.csv presentar conclusiones sobre la tasa de abandono de los empleados y generar un modelo de árboles de decisión para predecir la probabilidad de que una persona abandone la compañía
#
# -	Hacer una limpieza de los datos vacíos que no se pueden trabajar (analiza las columnas e identifica la mejor estrategia para no eliminar registros OJO registros no columnas)
#
# -	Analizar e identificar que columnas NO entregan valor en el conjunto de datos, justificar por qué no aportan valor a este análisis y porque se eliminaran
#
# -	genera gráficos sobre un análisis EDA frente a las variables categóricas de este conjunto identificando que variables no representan valor en el conjunto, justifícalo y elimina las columnas respectivas.
#
# -	según el análisis EDA realizado, reemplaza los registros vacíos por los de mayor concurrencia en esa columna
#
# -	genera gráficos sobre un análisis EDA frente a las variables numéricas de este conjunto identificando que variables no representan valor en el conjunto, justifícalo y elimina las columnas respectivas

# %% [markdown]
# #Insights
#
# - segun los analisis generados responde las siguientes preguntas:
#   - ¿Cuál es la tasa de abandono?
#   - ¿Hay un tipo de empleado que deja la empresa?
#
# - Genera conclusiones sobre que variables son las mas influyentes en la desicion de abandono de los empleados

# %% [markdown]
# ¿Cuál es el impacto económico de este problema? según un estudio "Cost of Turnover" del center for American progress:
#
# * El coste de la fuga de los empleados que ganan menos de 30000 es del 16.1% de su salario
#
# * El coste de la fuga de los empleados que ganan entre 30000-50000 es del 19.7% de su salario
#
# * El coste de la fuga de los empleados que ganan entre 50000-75000 es del 20.4% de su salario
#
# * El coste de la fuga de los empleados que ganan mas de 75000 es del 21% de su salario

# %% [markdown]
# - Vamos a comprobar este estudio con nuestro dataset, responde las siguientes preguntas:
#
#   - Cuanto ha costado esto el ultimo anio
#
#   - Cuanto cuestan los empleados no motivados (implicacion == baja)
#
# - Cuanto ahorraria a la compania Reducir un 10%, 20% y 30% de la fuga de empleados ahorraria a la compania $ cada anio.
#
# - cual es el porcentaje de abandono de los Sales Representative
#
# - Del area de ventas que estiamado un abandono (en cantidad de personas) se espera
#
# - Si se retiene al 30% de los representantes de ventas que abandonarian la compania que ahorro representaria

# %% [markdown]
# #Modelo de machine learning (arboles de decisión)
#
# -	genera un modelo de árboles de decisión que permita predecir si una persona abandonara la compañía
# -	evalúa el modelo y muestra el % de confianza del modelo
# -	genera un resultado en Excel que muestre la probabilidad de abandono de cada persona generado por el modelo
